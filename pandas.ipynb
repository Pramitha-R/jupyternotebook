# %%
import pandas as pd

# %%
df=pd.DataFrame(['MSFT','google','2016/1/1','2016/1/1'])

# %%
df.head()
# Out:
#           0
# 0      MSFT
# 1    google
# 2  2016/1/1
# 3  2016/1/1

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\pcc\\Downloads\\weather.csv')
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df['Data.Temperature.Min Temp'].max()
# Out:
# 88

# %%
df['Station.Location'][df['Station.State']=='Wyoming']
# Out:
# 310        Casper, WY
# 311      Cheyenne, WY
# 312        Lander, WY
# 313       Rawlins, WY
# 314      Sheridan, WY
#              ...
# 16738      Casper, WY
# 16739    Cheyenne, WY
# 16740      Lander, WY
# 16741     Rawlins, WY
# 16742    Sheridan, WY
# Name: Station.Location, Length: 265, dtype: object

# %%
import pandas as x
y=x.read_csv('C:\\Users\\pcc\\Documents\\w.csv')
y
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2023           32          6   rain
# 1  1/2/2023           35          7  sunny
# 2  1/3/2023           28          2   snow
# 3  1/4/2023           24          7   snow
# 4  1/5/2023           32          4   rain
# 5  1/6/2023           32          2  sunny

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
y.shape
# Out:
# (6, 4)

# %%
y.tail(3)
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2023           24          7   snow
# 4  1/5/2023           32          4   rain
# 5  1/6/2023           32          2  sunny

# %%
y.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.500000   4.666667
# std       3.885872   2.338090
# min      24.000000   2.000000
# 25%      29.000000   2.500000
# 50%      32.000000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
y[y.temperature==y['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2023           35          7  sunny

# %%
z=y.set_index('day')
z
# Out:
#           temperature  windspeed  event
# day
# 1/1/2023           32          6   rain
# 1/2/2023           35          7  sunny
# 1/3/2023           28          2   snow
# 1/4/2023           24          7   snow
# 1/5/2023           32          4   rain
# 1/6/2023           32          2  sunny

# %%
z.loc['1/3/2023']
# Out:
# temperature      28
# windspeed         2
# event          snow
# Name: 1/3/2023, dtype: object

# %%
import pandas as a
x=a.read_csv('C:\\Users\\pcc\\Documents\\w.csv')

# %%
d=a.DataFrame()
d
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
y
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2023           32          6   rain
# 1  1/2/2023           35          7  sunny
# 2  1/3/2023           28          2   snow
# 3  1/4/2023           24          7   snow
# 4  1/5/2023           32          4   rain
# 5  1/6/2023           32          2  sunny

# %%
import pandas as x
y=x.read_csv('C:\\Users\\pcc\\Documents\\w.csv')
y
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2023           32          6   rain
# 1  1/2/2023           35          7  sunny
# 2  1/3/2023           28          2   snow
# 3  1/4/2023           24          7   snow
# 4  1/5/2023           32          4   rain
# 5  1/6/2023           32          2  sunny

# %%
y.to_csv("C:\\Users\\pcc\\Documents\\new.csv",columns=['temperature','event'])

# %%
import pandas as a
def convert_to_temperature(cell):
    if cell=='35':
        return 37
    return cell
df=a.read_csv('C:\\Users\\pcc\\Documents\\W.csv',converters={
    'temperature':convert_to_temperature
})

df
# Out:
#         day temperature  windspeed  event
# 0  1/1/2023          32          6   rain
# 1  1/2/2023          37          7  sunny
# 2  1/3/2023          28          2   snow
# 3  1/4/2023          24          7   snow
# 4  1/5/2023          32          4   rain
# 5  1/6/2023          32          2  sunny

# %%
import pandas as pd
sq=pd.read_sql_table('Territory_Master', 'postgres:///sample_Asignment')  
sq
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 sq=pd.read_sql_table('Territory_Master', 'postgres:///sample_Asignment')
#       3 sq
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:280, in read_sql_table(table_name, con, schema, index_col, coerce_float, parse_dates, columns, chunksize)
#     215 def read_sql_table(
#     216     table_name: str,
#     217     con,
#    (...)
#     223     chunksize: int | None = None,
#     224 ) -> DataFrame | Iterator[DataFrame]:
#     225     """
#     226     Read SQL database table into a DataFrame.
#     227
#    (...)
#     278     >>> pd.read_sql_table('table_name', 'postgres:///db_name')  # doctest:+SKIP
#     279     """
# --> 280     pandas_sql = pandasSQL_builder(con, schema=schema)
# ...
